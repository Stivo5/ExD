# %%
import os
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
import triqs
from h5 import HDFArchive

# %%
A = HDFArchive('my_G2.h5', 'r')

# %%
A['G2']['dnup']['0000']['data']
# Out:
# array([[[-3.24033823e-05+2.63663012e-08j,
#          -4.46839479e-05-1.16044528e-08j,
#          -6.66800974e-05-1.86902778e-07j,
#          -1.12891907e-04-1.17966099e-06j,
#          -2.09093938e-04-1.22226268e-05j,
#           1.50254881e-04-2.32521050e-05j,
#           1.32150807e-04-8.51989707e-06j,
#           1.04631404e-04-6.91595049e-06j,
#           9.31871281e-05-9.93972329e-06j,
#           4.14721397e-04+1.86900763e-18j],
#         [-4.46887836e-05-1.55137167e-07j,
#          -6.20789233e-05-2.63866322e-07j,
#          -9.35083860e-05-5.94401225e-07j,
#          -1.60425706e-04-2.13361430e-06j,
#          -3.05199145e-04-1.81381935e-05j,
#           2.08687052e-04-3.52007359e-05j,
#           1.92078701e-04-1.49098247e-05j,
#           1.59899999e-04-1.70103657e-05j,
#           6.86329707e-04+1.54453220e-06j,
#           1.25902972e-04+1.50741602e-05j],
#         [-6.66896807e-05-7.37152746e-07j,
#          -9.35119780e-05-1.06762747e-06j,
# ...
