# %%
import os

maps = open(f"/proc/{os.getpid()}/maps").read()
print("\n".join(
    line for line in maps.splitlines()
    if "libstdc++.so.6" in line
))
# Out:
# 7ffff4bb2000-7ffff4e03000 r-xp 00000000 00:29 24741397                   /mnt/sw/nix/store/pxl9ndpq5yassys69ibkr3kcz34jh385-gcc-13.3.0/lib64/libstdc++.so.6.0.32
# 7ffff4e03000-7ffff5002000 ---p 00251000 00:29 24741397                   /mnt/sw/nix/store/pxl9ndpq5yassys69ibkr3kcz34jh385-gcc-13.3.0/lib64/libstdc++.so.6.0.32
# 7ffff5002000-7ffff500d000 r--p 00250000 00:29 24741397                   /mnt/sw/nix/store/pxl9ndpq5yassys69ibkr3kcz34jh385-gcc-13.3.0/lib64/libstdc++.so.6.0.32
# 7ffff500d000-7ffff5010000 rw-p 0025b000 00:29 24741397                   /mnt/sw/nix/store/pxl9ndpq5yassys69ibkr3kcz34jh385-gcc-13.3.0/lib64/libstdc++.so.6.0.32

# %%
from pomerol2triqs import PomerolED
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pomerol2triqs import PomerolED
#
# File /mnt/home/wentzell/opt/triqs_4.0.x_gcc/lib/python3.12/site-packages/pomerol2triqs/__init__.py:24
#       1 ################################################################################
#       2 #
#       3 # pomerol2triqs
#    (...)
#      19 #
#      20 ################################################################################
#      22 r"""pomerol2triqs Python module"""
# ---> 24 from .pomerol2triqs import PomerolED, BosonParams
#      26 __all__ = ['PomerolED', 'BosonParams']
#
# ...

# %%
# %%bash
# gcc --version
# g++ -print-file-name=libstdc++.so.6
# ldd /mnt/home/wentzell/opt/triqs_4.0.x_gcc/lib/python3.12/site-packages/pomerol2triqs/pomerol2triqs.cpython-312-x86_64-linux-gnu.so | grep -E 'libstdc\+\+|libgcc'
# Out:
# gcc (Spack GCC) 14.2.0
# Copyright (C) 2024 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# /mnt/sw/nix/store/772namg5pzy6wpdkv37sj5m9xd3wvc6i-gcc-14.2.0/lib/gcc/x86_64-pc-linux-gnu/14.2.0/../../../../lib64/libstdc++.so.6
# 	libstdc++.so.6 => /mnt/sw/nix/store/772namg5pzy6wpdkv37sj5m9xd3wvc6i-gcc-14.2.0/lib64/libstdc++.so.6 (0x00007ffff745d000)
# 	libgcc_s.so.1 => /mnt/sw/nix/store/772namg5pzy6wpdkv37sj5m9xd3wvc6i-gcc-14.2.0/lib64/libgcc_s.so.1 (0x00007ffff733e000)
