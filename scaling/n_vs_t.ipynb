# %%
from h5 import HDFArchive

import matplotlib.pyplot as plt

# %%
A = HDFArchive("n_vs_time.h5", 'r')

# %%
A["mesh_pt"]
# Out:
# array([ 10,  60, 110, 160, 210, 260, 310, 360, 410, 460, 510, 560, 610,
#        660, 710, 760, 810, 860, 910, 960])

# %%
A["time"]
# Out:
# [4.835857687998214,
#  0.12844618198869284,
#  0.2899428669916233,
#  0.7183294569986174,
#  0.899894171001506,
#  1.3655900159938028,
#  1.9602844589971937,
#  2.7237710879999213,
#  3.74521223299962,
#  4.227840323001146,
#  5.157663878999301,
#  6.246665098005906,
#  7.35476949698932,
#  8.662914440996246,
#  10.052951953999582,
#  11.524512000993127,
#  13.147112086997367,
#  14.866425398009596,
#  16.632390913000563,
#  18.866135584001313]

# %%
# A["G"][4]

# %%
fig, axes = plt.subplots(1,1)
axes.plot(A["mesh_pt"][1:], A["time"][1:])

# %%
fig, axes = plt.subplots(1,1)
axes.plot(A["time"][1:], A["mesh_pt"][1:]**2)
