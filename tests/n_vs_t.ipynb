# %%
from h5 import HDFArchive

import matplotlib.pyplot as plt

# %%
A = HDFArchive("n_vs_time.h5", 'r')

# %%
A["mesh_pt"]
# Out:
# array([ 10,  60, 110, 160, 210, 260, 310, 360, 410, 460, 510, 560, 610,
#        660, 710, 760, 810, 860, 910, 960])

# %%
A["time"]
# Out:
# [2.342275206989143,
#  0.13898887499817647,
#  0.3398218500078656,
#  0.6769566090079024,
#  1.2506296110223047,
#  1.5447176139859948,
#  2.0994426700053737,
#  2.7029979630024172,
#  3.6943915509909857,
#  4.6497120179992635,
#  5.3594493879936635,
#  6.411047828005394,
#  7.485358404024737,
#  9.090966905001551,
#  10.241750221990515,
#  11.732443567016162,
#  13.436312247009482,
#  15.054185515007703,
#  16.949298630002886,
#  18.905060024990235]

# %%
A["G"][4]
# Out:
# Greens Function 4 with mesh Imaginary Freq Mesh with beta = 2, statistic = Fermion, n_iw = 210, positive_only = false, Imaginary Freq Mesh with beta = 2, statistic = Fermion, n_iw = 210, positive_only = false and target_shape ():

# %%
fig, axes = plt.subplots(1,1)
axes.plot(A["mesh_pt"][1:], A["time"][1:])
