# %%
from h5 import HDFArchive

# %%
A = HDFArchive("n_vs_time.h5", 'r')

# %%
A["mesh_pt"]
# Out:
# array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50])

# %%
A["time"]
# Out:
# [2.3287775259959744,
#  0.02231770200887695,
#  0.03192731901071966,
#  0.04332708800211549,
#  0.0433711900113849,
#  0.04762784400372766,
#  0.05496973200934008,
#  0.06833954100147821,
#  0.07880429399665445,
#  0.06884368800092489]
